# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielRGuillen/operation_enchante_fans/blob/main/EDA_waiters_op_enchante_fans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
import pandas as pd

# get credentials
auth.authenticate_user()

query = '''
SELECT *
FROM `operation-enchante-fans.franquicias_pro_fans.waiters`
'''
waiters_df = pd.read_gbq(query, project_id="operation-enchante-fans")
waiters_df.head()
# Out:
#    int64_field_0  id_waiter      Name   Surname         DOB Sex MaritalDesc  \
# 0              2      14172     Jenna  Dietrich  2002-05-14   F      Single
# 1             42      24920       Mia     Brown  2002-11-24   F     Married
# 2             34      24833      Hong      Pham  2003-03-06  M      Married
# 3              3      24921    Bianca  Roehrich  1988-05-27   F      Single
# 4              7      14172  Erasumus  Monkfish  2003-08-07  M      Married
#
#    HispanicLatino                   RaceDesc PerformanceScore  \
# 0            True                      White              PIP
# 1           False  Black or African American      Fully Meets
# 2           False                      Asian      Fully Meets
# 3            True                      White      Fully Meets
# 4           False                      White      Fully Meets
#
#    EngagementSurvey  EmpSatisfaction  Absences  Salary
# 0              2.30                1        17   33356
# ...

# %%
waiters_df.shape
# Out:
# (57, 14)

# %%
waiters_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   int64_field_0     57 non-null     Int64
#  1   id_waiter         55 non-null     Int64
#  2   Name              57 non-null     object
#  3   Surname           57 non-null     object
#  4   DOB               57 non-null     dbdate
#  5   Sex               57 non-null     object
#  6   MaritalDesc       57 non-null     object
#  7   HispanicLatino    57 non-null     boolean
#  8   RaceDesc          57 non-null     object
#  9   PerformanceScore  57 non-null     object
#  10  EngagementSurvey  57 non-null     float64
#  11  EmpSatisfaction   57 non-null     Int64
#  12  Absences          57 non-null     Int64
#  13  Salary            57 non-null     Int64
# dtypes: Int64(5), boolean(1), dbdate(1), float64(1), object(6)
# memory usage: 6.3+ KB

# %%
waiters_df.isnull().sum()
# Out:
# int64_field_0       0
# id_waiter           2
# Name                0
# Surname             0
# DOB                 0
# Sex                 0
# MaritalDesc         0
# HispanicLatino      0
# RaceDesc            0
# PerformanceScore    0
# EngagementSurvey    0
# EmpSatisfaction     0
# Absences            0
# Salary              0
# dtype: int64
