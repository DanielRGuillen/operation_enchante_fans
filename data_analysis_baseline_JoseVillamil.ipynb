# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielRGuillen/operation_enchante_fans/blob/jose_waiters2/data_analysis_baseline_JoseVillamil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import auth
# get credentials
auth.authenticate_user()

query = '''
SELECT * FROM
`operation-enchante-fans.franquicias_pro_fans.order_line`
'''
data_order_line = pd.read_gbq(query, project_id="operation-enchante-fans")
data_order_line.head()
# Out:
#    int64_field_0  id_order_line  id_order              date_opended  \
# 0         864471       80615871  16076249 2017-11-11 12:17:24+00:00
# 1        3206563      110979722  23083049 2018-03-10 12:14:12+00:00
# 2        1435406      102446967  21057603 2018-02-10 13:22:57+00:00
# 3         137161      106807474  22058674 2018-02-24 11:48:27+00:00
# 4         173829      164282937  36548544 2018-07-26 11:19:51+00:00
#
#                date_created  quantity  unit_price  discount_amount     type  \
# 0 2017-11-11 12:17:55+00:00       1.0         0.0              0.0  PRODUCT
# 1 2018-03-10 12:40:05+00:00       1.0         0.0              0.0  PRODUCT
# 2 2018-02-10 13:24:21+00:00       1.0         0.0              0.0  PRODUCT
# 3 2018-02-24 11:48:55+00:00       1.0         0.0              0.0  PRODUCT
# 4 2018-07-26 11:21:41+00:00       1.0         0.0              0.0  PRODUCT
#
#   feature_type unit_measure   item_category item_name
# ...

# %%
# !pip install dabl
# !pip install -U matplotlib

# %%
import dabl

dabl.plot(data_order_line, target_col = 'unit_price', verbose=100)
# Out:
# Target looks like regression
# /usr/local/lib/python3.10/dist-packages/dabl/plot/utils.py:704: UserWarning:
#
# Dropped 18350 outliers in column unit_price.
#
# /usr/local/lib/python3.10/dist-packages/dabl/plot/supervised.py:652: UserWarning:
#
# Discarding 18350 outliers in target column.
#
# /usr/local/lib/python3.10/dist-packages/dabl/plot/utils.py:704: UserWarning:
#
# Dropped 1969 outliers in column unit_price.
#
# /usr/local/lib/python3.10/dist-packages/dabl/plot/supervised.py:107: UserWarning:
#
# Not plotting highly correlated (0.9999991019863151) feature id_order_line. Set prune_correlations_threshold=0 to keep.
#
# /usr/local/lib/python3.10/dist-packages/dabl/plot/utils.py:704: UserWarning:
#
# Dropped 1969 outliers in column unit_price.
# [<Axes: title={'center': 'Target distribution'}, xlabel='unit_price', ylabel='frequency'>,
#  array([[<Axes: title={'center': 'F=2.17E-01'}, xlabel='int64_field_0', ylabel='unit_price'>,
# ...
