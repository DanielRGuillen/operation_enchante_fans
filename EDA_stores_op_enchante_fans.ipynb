# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielRGuillen/operation_enchante_fans/blob/main/EDA_stores_op_enchante_fans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
import pandas as pd

# get credentials
auth.authenticate_user()

query = '''
SELECT *
FROM `operation-enchante-fans.franquicias_pro_fans.stores`
'''
stores_df = pd.read_gbq(query, project_id="operation-enchante-fans")
stores_df.head()
# Out:
#    int64_field_0  id_store              date_created country        city  \
# 0             16      5860 2018-01-29 08:52:26+00:00  France  Strasbourg
# 1             14      1513 2016-03-15 17:34:25+00:00  France      Rennes
# 2              4      5281 2017-12-08 11:09:59+00:00  France        Lyon
# 3              5      7872 2018-09-25 16:04:17+00:00  France        Lyon
# 4              1       351 2015-07-25 11:51:52+00:00  France     Castres
#
#                                  team                       stadium  \
# 0    Racing Club de Strasbourg Alsace            Stade de la Meinau
# 1                       Stade Rennais  Stade de la Route de Lorient
# 2                  Olympique Lyonnais       Parc Olympique Lyonnais
# 3  Lyon Olympique Universitaire Rugby              Stade de Gerland
# 4                   Castres Olympique          Stade Pierre Antoine
#
#          other_name  capacity                               stadium_adress  \
# ...

# %%
stores_df.shape
# Out:
# (21, 17)

# %% [markdown]
# #Verificando valores Nulos y tipo de datos

# %%
stores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   int64_field_0      21 non-null     Int64
#  1   id_store           21 non-null     Int64
#  2   date_created       21 non-null     datetime64[ns, UTC]
#  3   country            21 non-null     object
#  4   city               21 non-null     object
#  5   team               21 non-null     object
#  6   stadium            21 non-null     object
#  7   other_name         11 non-null     object
#  8   capacity           21 non-null     Int64
#  9   stadium_adress     21 non-null     object
#  10  stadium_latitude   21 non-null     float64
#  11  stadium_longitude  21 non-null     float64
#  12  store_name         21 non-null     object
#  13  review_count       21 non-null     Int64
#  14  rating             21 non-null     float64
# ...

# %%
stores_df.isnull().sum()
# Out:
# int64_field_0         0
# id_store              0
# date_created          0
# country               0
# city                  0
# team                  0
# stadium               0
# other_name           10
# capacity              0
# stadium_adress        0
# stadium_latitude      0
# stadium_longitude     0
# store_name            0
# review_count          0
# rating                0
# price                 3
# selling_way           0
# dtype: int64
