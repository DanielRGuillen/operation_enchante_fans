# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielRGuillen/operation_enchante_fans/blob/main/EDA_payments_op_enchante_fans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
import pandas as pd

# get credentials
auth.authenticate_user()

query = '''
SELECT *
FROM `operation-enchante-fans.franquicias_pro_fans.payments`
'''
payments_df = pd.read_gbq(query, project_id="operation-enchante-fans")
payments_df.head()
# Out:
#    int64_field_0     id_pay   id_order    status                 type  amount  \
# 0              1   40764122   29576034  ACCEPTED  Contactless payment    16.7
# 1              3    4835058    3387309  ACCEPTED     AMERICAN_EXPRESS   312.0
# 2             10   75724804   57565696  ACCEPTED           BANK_CHECK   402.0
# 3             12  151356792  119477601  ACCEPTED  Contactless payment    31.5
# 4             13   96186982   74232923  ACCEPTED               OTHERS    84.0
#
#    cashback  credit              date_created
# 0       0.0     0.0 2018-05-23 11:47:06+00:00
# 1       0.0     0.0 2016-10-21 12:24:56+00:00
# 2       0.0     0.0 2019-01-29 12:05:57+00:00
# 3       0.0     0.0 2020-02-20 19:48:53+00:00
# 4       0.0     0.0 2019-05-25 18:51:16+00:00

# %%
payments_df.shape
# Out:
# (1403086, 9)

# %% [markdown]
# #Verificando valores Nulos y tipo de datos

# %%
payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1403086 entries, 0 to 1403085
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   int64_field_0  1403086 non-null  Int64
#  1   id_pay         1403086 non-null  Int64
#  2   id_order       1403086 non-null  Int64
#  3   status         1403086 non-null  object
#  4   type           1403082 non-null  object
#  5   amount         1403086 non-null  float64
#  6   cashback       1403070 non-null  float64
#  7   credit         1403070 non-null  float64
#  8   date_created   1403086 non-null  datetime64[ns, UTC]
# dtypes: Int64(3), datetime64[ns, UTC](1), float64(3), object(2)
# memory usage: 100.4+ MB

# %%
payments_df.isnull().sum()
# Out:
# int64_field_0     0
# id_pay            0
# id_order          0
# status            0
# type              4
# amount            0
# cashback         16
# credit           16
# date_created      0
# dtype: int64
